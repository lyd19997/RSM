# %%
#!/usr/bin/env Python
# coding=utf-8
import os
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# 计算最终受益

# %%
def parse_data(filename):
#     result = {}
    peak = list()
    usageTime = list()
    income, cost = 0, 0
    period = 10
    with open(filename, 'r+') as file_to_read:
        lines = file_to_read.readline() # 整行读取数据
        lines = file_to_read.readline()
#         result['runtime'] = float(lines.split()[0])
        lines = file_to_read.readline()
#         result['receiveNum'] = int(lines.split()[0])
        lines = file_to_read.readline()
#         result['reqNum'] = int(lines.split()[0])
        lines = file_to_read.readline()
        income = float(lines.split()[0])
        lines = file_to_read.readline()
        cost = float(lines.split()[0])
        while True:
            lines = file_to_read.readline() # 整行读取数据
            if not lines:
                break
            if "--peakPerEdge--" in lines:
                break
        lines = file_to_read.readline()
        peak = [float(i) for i in lines.split()]
        while True:
            lines = file_to_read.readline() # 整行读取数据
            if not lines:
                break
            if "--volPerTimeEdge--" in lines:
                break
        while True:
            lines = file_to_read.readline() # 整行读取数据
            if not lines:
                break
            u_temp = [float(i) for i in lines.split()]
            usageTime.append(u_temp)
        peak = np.array(peak)
        usageTime = np.array(usageTime)
#     result['peak'] = peak
#     result['usageTime'] = usageTime
    usageTime = usageTime.T
#     print(len(usageTime))
#     print(len(peak))
    usageEdge = list()
    for i in range(len(peak)):
        if peak[i]:
#             print(peak[i])
            usageEdge.append(sum(usageTime[i]) / period / peak[i])
    #     for price in bandwidthPrice:
    #         result[price] = 0
    #     for i in range(len(peak)):
    #         result[bandwidthPrice[i]] += peak[i]
#     print(result)
#         if not peak[i]:
#             usageEdge.append(0)
#             continue
#     usageEdge.append(sum(usageTime[i]) / period / peak[i])
#     price.append(bandwidthPrice[i])
#     usageEdge.append(sum(usageTime[i]) / period / peak[i])
#     price.append(1)

#     print(usageEdge)
    return income - cost

       
#     print(usageEdge)
#     keys = sorted(result.keys())
#     keys.sort()
#     for key in keys:
#         print (key)
#     return [result[key] for key in keys]

# %%
algs = ["srm", "greedy"]
lambda_ = list()
srm, greedy = list(), list()
for i in range(10, 60, 10):
    lambda_.append(str(i))
    print(i)
# print(lambda_)
for alg in algs:
    print(alg)
    for lam in lambda_:
#         print(lam)
        data = parse_data(os.path.join(alg, lam + '.txt'))
        print(data)
        if alg == 'srm':
            srm.append(data)
        if alg == 'greedy':
            greedy.append(data)
            
            
print(srm)
print(greedy)
print([(srm[i] - greedy[i])/ srm[i] for i in range(len(lambda_))])
# Out:
# 10
# 20
# 30
# 40
# 50
# srm
# 15803.400000000001
# 42186.0
# 81952.0
# 85692.0
# 128201.0
# greedy
# 8083.0
# 18761.6
# 39758.0
# 41647.0
# 65922.0
# [15803.400000000001, 42186.0, 81952.0, 85692.0, 128201.0]
# [8083.0, 18761.6, 39758.0, 41647.0, 65922.0]
# [0.48852778516015544, 0.5552647797847627, 0.514862358453729, 0.5139919712458573, 0.48579184249732843]

# %%
bandwidthPrice = list()
vertexNum, EdgeNum = 0, 0
with open("Topo_node_10.txt", 'r+') as file:
    line = file.readline()
    vertexNum, EdgeNum = [int(i) for i in line.split()]
    for i in range(EdgeNum):
        line = file.readline()
        src, dst, price, lim = [int(i) for i in line.split()]
        bandwidthPrice.append(price)
        bandwidthPrice.append(price)

# %%
print (bandwidthPrice)
# Out:
# [50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50]

# %% [markdown]
# 计算请求接受率

# %%
def acceptance_data(filename):
#     result = {}
    peak = list()
    usageTime = list()
    period = 10
    receiveNum = 0
    reqNum = 0
    with open(filename, 'r+') as file_to_read:
        lines = file_to_read.readline() # 整行读取数据
        lines = file_to_read.readline()
#         result['runtime'] = float(lines.split()[0])
        lines = file_to_read.readline()
        receiveNum = int(lines.split()[0])
        lines = file_to_read.readline()
        reqNum = int(lines.split()[0])
        lines = file_to_read.readline()
#         result['income'] = int(lines.split()[0])
        lines = file_to_read.readline()
#         result['cost'] = int(lines.split()[0])
        while True:
            lines = file_to_read.readline() # 整行读取数据
            if not lines:
                break
            if "--peakPerEdge--" in lines:
                break
        lines = file_to_read.readline()
        peak = [float(i) for i in lines.split()]
        while True:
            lines = file_to_read.readline() # 整行读取数据
            if not lines:
                break
            if "--volPerTimeEdge--" in lines:
                break
        while True:
            lines = file_to_read.readline() # 整行读取数据
            if not lines:
                break
            u_temp = [float(i) for i in lines.split()]
            usageTime.append(u_temp)
        peak = np.array(peak)
        usageTime = np.array(usageTime)
#     result['peak'] = peak
#     result['usageTime'] = usageTime
    usageTime = usageTime.T
#     print(len(usageTime))
#     print(len(peak))
    usageEdge = list()
    return receiveNum / reqNum

# %%
algs = ["srm", "greedy"]
lambda_ = list()
# lambda_ = ["50", "100", "150", "200"]
for i in range(10, 60, 10):
    lambda_.append(str(i))
    print(i)
for alg in algs:
    print(alg)
    for lam in lambda_:
#         print(lam)
        print(acceptance_data(os.path.join(alg, lam + '.txt')))
# Out:
# 10
# 20
# 30
# 40
# 50
# srm
# 0.7203947368421053
# 0.8610400682011935
# 0.7928692699490663
# 0.8104969809568044
# 0.8436482084690554
# greedy
# 0.17763157894736842
# 0.2710997442455243
# 0.3593661573288059
# 0.3353460287970274
# 0.36807817589576547

# %% [markdown]
# 计算带宽利用率

# %%
def parse_data(filename, bandwidthPrice):
    result = {}
    flow = dict()
    peak = list()
    usageTime = list()
    period = 50
    with open(filename, 'r+') as file_to_read:
        lines = file_to_read.readline() # 整行读取数据
        lines = file_to_read.readline()
#         result['runtime'] = float(lines.split()[0])
        lines = file_to_read.readline()
        receiveNum = int(lines.split()[0])
#         result['receiveNum'] = int(lines.split()[0])
        lines = file_to_read.readline()
        reqNum = int(lines.split()[0])
#         return receiveNum / reqNum
#         result['reqNum'] = int(lines.split()[0])
        lines = file_to_read.readline()
#         return(float(lines.split()[0]))
#         result['income'] = int(lines.split()[0])
        lines = file_to_read.readline()
#         return(int(lines.split()[0]))#return cost
        while True:
            lines = file_to_read.readline() # 整行读取数据
            if not lines:
                break
            if "--peakPerEdge--" in lines:
                break
        lines = file_to_read.readline()
        peak = [float(i) for i in lines.split()]
        while True:
            lines = file_to_read.readline() # 整行读取数据
            if not lines:
                break
            if "--volPerTimeEdge--" in lines:
                break
        while True:
            lines = file_to_read.readline() # 整行读取数据
            if not lines:
                break
            u_temp = [float(i) for i in lines.split()]
            usageTime.append(u_temp)
        peak = np.array(peak)
        usageTime = np.array(usageTime)
    
#     return usage
#     for price in bandwidthPrice:
#         result[price] = 0
#         flow[price] = 0
#     for price in bandwidthPrice:
#         result[price] += 1
#     for i in range(len(peak)):
#         flow[bandwidthPrice[i]] += peak[i]
# #         for t in range(len(usageTime)):
# #             flow[bandwidthPrice[i]] += usageTime[t][i]
#     for key in result.keys():
#         result[key] = flow[key]  
#     keys = sorted(result.keys())
# # #     keys.sort()
#     for key in keys:
#         print (key)
#     return [result[key] for key in keys]

    usageTime = usageTime.T
    result = list()
    for i in range(len(peak)):
        if peak[i]:
            temp = list()
            for t in range(len(usageTime[i])):
                if usageTime[i][t]  > 0.5 * peak[i]:
                    temp.append(usageTime[i][t])
            if temp:
                result.append(sum(temp)/len(temp)/peak[i])
#             else: result.append(0)
#     print(len(result))
    return sum(result)/len(result)
        
            
#     result['peak'] = peak
#     result['usageTime'] = usageTime
#     usageTime = usageTime.T
#     usageEdge = list()
    
# #     print(result)
# #         if not peak[i]:
# #             usageEdge.append(0)
# #             continue
# #         usageEdge.append(bandwidthPrice[i] * sum(usageTime[i]) / period / peak[i])
# #         price.append(bandwidthPrice[i])
# #         usageEdge.append(sum(usageTime[i]) / period / peak[i])
# #         price.append(1)

       
# #     print(usageEdge)

# %%
algs = ["srm", "greedy"]
for alg in algs:
    print(alg)
    for lam in lambda_:
#         print(lam)
        print(parse_data(os.path.join(alg, lam + '.txt'), bandwidthPrice))
# Out:
# srm
# 0.791753777147
# 0.821854185538
# 0.838171392924
# 0.869189558208
# 0.873541263154
# greedy
# 0.908729697828
# 0.871434627382
# 0.888394240455
# 0.899408644962
# 0.917887971955

# %%
def parse_data(filename, bandwidthPrice):
    result = {}
    flow = dict()
    peak = list()
    usageTime = list()
    period = 50
    with open(filename, 'r+') as file_to_read:
        lines = file_to_read.readline() # 整行读取数据
        lines = file_to_read.readline()
#         result['runtime'] = float(lines.split()[0])
        lines = file_to_read.readline()
#         result['receiveNum'] = int(lines.split()[0])
        lines = file_to_read.readline()
#         result['reqNum'] = int(lines.split()[0])
        lines = file_to_read.readline()
#         result['income'] = int(lines.split()[0])
        lines = file_to_read.readline()
#         return(int(lines.split()[0]))#return cost
        while True:
            lines = file_to_read.readline() # 整行读取数据
            if not lines:
                break
            if "--peakPerEdge--" in lines:
                break
        lines = file_to_read.readline()
        peak = [float(i) for i in lines.split()]
        while True:
            lines = file_to_read.readline() # 整行读取数据
            if not lines:
                break
            if "--volPerTimeEdge--" in lines:
                break
        while True:
            lines = file_to_read.readline() # 整行读取数据
            if not lines:
                break
            u_temp = [float(i) for i in lines.split()]
            usageTime.append(u_temp)
        peak = np.array(peak)
        usageTime = np.array(usageTime)
    
#     return usage
    for price in bandwidthPrice:
        result[price] = 0
        flow[price] = 0
    for price in bandwidthPrice:
        result[price] += 1
    for i in range(len(peak)):
        flow[bandwidthPrice[i]] += peak[i]
#         for t in range(len(usageTime)):
#             flow[bandwidthPrice[i]] += usageTime[t][i]
    for key in result.keys():
        result[key] = flow[key]  
    keys = sorted(result.keys())
# #     keys.sort()
    for key in keys:
        print (key)
    return [result[key] for key in keys]

#     usageTime = usageTime.T
#     result = list()
#     for i in range(len(peak)):
#         if peak[i]:
#             temp = list()
#             for t in range(len(usageTime[i])):
#                 if usageTime[i][t]  > 0.3 * peak[i]:
#                     temp.append(usageTime[i][t])
#             if temp:
#                 result.append(sum(temp)/len(temp)/peak[i])
# #     print(len(result))
#     return sum(result)/len(result)
        
            
#     result['peak'] = peak
#     result['usageTime'] = usageTime
#     usageTime = usageTime.T
#     usageEdge = list()
    
# #     print(result)
# #         if not peak[i]:
# #             usageEdge.append(0)
# #             continue
# #         usageEdge.append(bandwidthPrice[i] * sum(usageTime[i]) / period / peak[i])
# #         price.append(bandwidthPrice[i])
# #         usageEdge.append(sum(usageTime[i]) / period / peak[i])
# #         price.append(1)

       
# #     print(usageEdge)

# %%
algs = ["srm", "greedy"]
# for alg in algs:
#     print(alg)
#     for lam in lambda_:
# #         print(lam)
#         print(parse_data(os.path.join(alg, lam + '.txt'), bandwidthPrice))
for lam in lambda_:
    print("----------")
    for alg in algs:
        print(alg)
        print(parse_data(os.path.join(alg, lam + '.txt'), bandwidthPrice))
# Out:
# ----------
# srm
# 50
# [982.0]
# greedy
# 50
# [306.0]
# ----------
# srm
# 50
# [2857.0]
# greedy
# 50
# [728.0]
# ----------
# srm
# 50
# [3416.0]
# greedy
# 50
# [1393.0]
# ----------
# srm
# 50
# [4332.0]
# greedy
# 50
# [1515.0]
# ----------
# srm
# 50
# [6480.0]
# greedy
# 50
# [2405.0]

# %% [markdown]
# throughput

# %%
def throughput(filename):
#     result = {}
    peak = list()
    usageTime = list()
    period = 10
    receiveNum = 0
    reqNum = 0
    with open(filename, 'r+') as file_to_read:
        lines = file_to_read.readline() # 整行读取数据
        lines = file_to_read.readline()
#         result['runtime'] = float(lines.split()[0])
        lines = file_to_read.readline()
        receiveNum = int(lines.split()[0])
        lines = file_to_read.readline()
        reqNum = int(lines.split()[0])
        lines = file_to_read.readline()
#         result['income'] = int(lines.split()[0])
        lines = file_to_read.readline()
#         result['cost'] = int(lines.split()[0])
        while True:
            lines = file_to_read.readline() # 整行读取数据
            if not lines:
                break
            if "--peakPerEdge--" in lines:
                break
        lines = file_to_read.readline()
        peak = [float(i) for i in lines.split()]
        while True:
            lines = file_to_read.readline() # 整行读取数据
            if not lines:
                break
            if "--volPerTimeEdge--" in lines:
                break
        while True:
            lines = file_to_read.readline() # 整行读取数据
            if not lines:
                break
            u_temp = [float(i) for i in lines.split()]
            usageTime.append(u_temp)
        peak = np.array(peak)
        usageTime = np.array(usageTime)
    return sum([sum(usage) for usage in usageTime])

# %%
algs = ["srm", "greedy"]
for alg in algs:
    print(alg)
    for lam in lambda_:
#         print(lam)
        print(throughput(os.path.join(alg, lam + '.txt')))
# Out:
# srm
# 13495.17876
# 42584.142059
# 53505.70319
# 66590.147
# 102863.7374
# greedy
# 4769.1946866
# 11880.243491
# 24481.55297
# 26575.43269
# 43506.0847

# %%
def throughputTime(filename):
#     result = {}
    peak = list()
    usageTime = list()
    period = 10
    receiveNum = 0
    reqNum = 0
    with open(filename, 'r+') as file_to_read:
        lines = file_to_read.readline() # 整行读取数据
        lines = file_to_read.readline()
#         result['runtime'] = float(lines.split()[0])
        lines = file_to_read.readline()
        receiveNum = int(lines.split()[0])
        lines = file_to_read.readline()
        reqNum = int(lines.split()[0])
        lines = file_to_read.readline()
#         result['income'] = int(lines.split()[0])
        lines = file_to_read.readline()
#         result['cost'] = int(lines.split()[0])
        while True:
            lines = file_to_read.readline() # 整行读取数据
            if not lines:
                break
            if "--peakPerEdge--" in lines:
                break
        lines = file_to_read.readline()
        peak = [float(i) for i in lines.split()]
        while True:
            lines = file_to_read.readline() # 整行读取数据
            if not lines:
                break
            if "--volPerTimeEdge--" in lines:
                break
        while True:
            lines = file_to_read.readline() # 整行读取数据
            if not lines:
                break
            u_temp = [float(i) for i in lines.split()]
            usageTime.append(u_temp)
        peak = np.array(peak)
        usageTime = np.array(usageTime)
    return [sum(usage) for usage in usageTime]

# %%
for lam in lambda_:
    print("----------" + str(lam))
    for alg in algs:
        print(alg)
        thrp = throughputTime(os.path.join(alg, lam + '.txt'))
        for thr in thrp:
            print(thr)
# Out:
# ----------10
# srm
# 318.040767
# 563.40952
# 709.73245
# 919.40606
# 1116.64507
# 1301.56856
# 1299.5974
# 1387.91674
# 1402.83517
# 1456.92428
# 1604.0779
# 1480.88639
# 1461.07583
# 1527.53941
# 1595.34465
# 1393.52967
# 1278.89005
# 1053.392483
# 792.937377
# 449.7091071
# greedy
# 190.946294
# 463.84002
# 529.09759
# 599.00427
# 721.52153
# 823.90666
# 876.46976
# 885.00261
# 921.99121
# 910.62467
# 1019.089
# 1003.35852
# 1034.23012
# 969.62651
# 990.18753
# 861.22823
# 946.734056
# 772.751467
# 597.678427
# 337.020026
# ----------20
# srm
# 395.62534
# 958.266052
# 1427.37567
# 1704.5462
# 1971.4335
# 2302.9611
# 2356.4186
# 2546.8386
# 2512.961
# 2643.7691
# 2753.3979
# 2823.1006
# 2751.3251
# 2677.8747
# 2757.1145
# 2735.2044
# 2358.805
# 1879.62685
# 1329.80687
# 780.479749
# greedy
# 337.0075
# 621.163425
# 974.745195
# 1171.345888
# 1306.20914
# 1730.02712
# 1784.02822
# 1815.32792
# 1884.68202
# 2002.60892
# 1956.67412
# 2076.20934
# 2049.19711
# 1971.25941
# 1997.34962
# 1987.30072
# 1759.31811
# 1476.78078
# 1061.57388
# 558.396905
# ----------30
# srm
# 813.48913
# 1726.19211
# 2539.19289
# 3022.8879
# 3499.732
# 3747.2153
# 3892.6481
# 3614.5962
# 3741.2367
# 4108.0752
# 4009.98402
# 4137.1055
# 4225.72805
# 4164.96343
# 4206.38988
# 4161.1211
# 4171.7206
# 3078.63252
# 2264.46272
# 1150.34701
# greedy
# 613.50232
# 1136.09935
# 1791.6037
# 2266.7148
# 2702.6665
# 3162.9473
# 3382.2446
# 3239.7857
# 3362.0765
# 3548.8777
# 3573.2828
# 3637.1543
# 3722.2241
# 3665.8578
# 3633.3858
# 3538.8885
# 3267.8445
# 2617.4077
# 1960.5286
# 1021.54558
# ----------40
# srm
# 1358.2825
# 2607.2511
# 2622.819
# 3197.5138
# 3760.8374
# 3878.6217
# 4168.2711
# 4827.2354
# 4669.58663
# 5045.3437
# 5372.4748
# 5525.2161
# 5561.0135
# 5636.5911
# 5555.3098
# 5461.5902
# 5252.8539
# 3988.7664
# 2579.6246
# 1130.75229
# greedy
# 817.99817
# 1552.662
# 1557.50715
# 2044.6177
# 2698.9951
# 2963.06
# 3177.3842
# 3427.2826
# 3484.1392
# 3858.2408
# 4028.3167
# 4178.7158
# 4156.5259
# 4149.9961
# 4200.8797
# 4103.65152
# 3852.07622
# 2973.99402
# 2075.53017
# 891.32007
# ----------50
# srm
# 1292.584894
# 2507.34623
# 3787.69897
# 4514.26336
# 5472.85694
# 6238.47036
# 6597.925344
# 7208.45208
# 7273.278974
# 7354.187564
# 7247.406205
# 7263.193408
# 7315.864478
# 7455.4245
# 7532.01847
# 7303.934553
# 7054.81361
# 5436.38037
# 3450.9403
# 1870.14359
# greedy
# 881.31963
# 1888.1611
# 2783.4116
# 3676.5716
# 4550.8782
# 5043.1653
# 5405.7197
# 5716.4763
# 5842.9446
# 5855.5044
# 5721.2881
# 5683.2271
# 5700.7696
# 5727.8345
# 5766.2012
# 5621.8291
# 5173.5545
# 3878.7998
# 2434.66621
# 1281.69329
